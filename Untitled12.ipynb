# %%
# !pip install -q google-genai

# %%
from google.colab import userdata
from google import genai

API_KEY = userdata.get("GEMINI_API_KEY")

client = genai.Client(api_key=API_KEY)

# %%
question = input("Ask your question: ")
# Out:
# Ask your question: explain ai

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=question
)

print(response.text)
# Out:
# AI, or **Artificial Intelligence**, is a broad field of computer science that aims to create machines that can perform tasks that typically require human intelligence.
#
# In simpler terms, it's about **making computers "think" or "learn" like humans.**
#
# Here's a breakdown of what that means and how it works:
#
# ---
#
# ### What is AI Trying to Achieve?
#
# AI systems are designed to simulate or mimic cognitive functions that we associate with the human mind, such as:
#
# 1.  **Learning:** Acquiring information and rules for using the information.
# 2.  **Reasoning:** Using rules to reach approximate or definite conclusions.
# 3.  **Problem-solving:** Finding solutions to complex problems.
# 4.  **Perception:** Recognizing objects, sounds, and other sensory input.
# 5.  **Language understanding:** Comprehending and generating human language.
# 6.  **Decision-making:** Choosing the best course of action from various alternatives.
#
# ---
#
# ### How Does AI Work (in a Nutshell)?
#
# At its core, AI works by processing vast amounts of data using complex algorithms to identify patterns, make predictions, or take actions. Instead of being explicitly programmed for every single scenario, AI systems are *trained* to learn from data.
#
# The main techniques behind modern AI include:
#
# *   **Machine Learning (ML):** This is the most common way AI is implemented today. ML algorithms learn from data without being explicitly programmed.
#     *   **Supervised Learning:** The algorithm learns from labeled data (e.g., showing it thousands of cat pictures labeled "cat" and dog pictures labeled "dog" so it can identify new ones).
#     *   **Unsupervised Learning:** The algorithm finds patterns in unlabeled data on its own (e.g., grouping customers with similar buying habits).
#     *   **Reinforcement Learning:** The algorithm learns by trial and error, receiving rewards for good actions and penalties for bad ones (e.g., training an AI to play chess or video games).
# *   **Deep Learning (DL):** A subfield of machine learning that uses artificial neural networks with multiple layers (hence "deep") to learn complex patterns. Deep learning is particularly effective for tasks like image recognition, speech recognition, and natural language processing. It's inspired by the structure and function of the human brain.
# *   **Natural Language Processing (NLP):** Enables computers to understand, interpret, and generate human language. (Think chatbots, language translation, sentiment analysis).
# *   **Computer Vision:** Allows computers to "see" and interpret visual information from images and videos. (Used in facial recognition, self-driving cars, medical image analysis).
#
# ---
#
# ### Types of AI
#
# AI is often categorized by its capabilities:
#
# 1.  **Narrow AI (or Weak AI):** This is all the AI that exists today. It's designed and trained for a *specific task*.
#     *   **Examples:** Siri, Google Assistant, recommendation engines (Netflix, Amazon), spam filters, chess programs, self-driving cars (only for driving, not writing poetry).
#     *   **Characteristics:** Highly proficient at its narrow task, but has no genuine consciousness, self-awareness, or general intelligence outside its domain.
#
# 2.  **Artificial General Intelligence (AGI or Strong AI):** This is hypothetical AI that can understand, learn, and apply intelligence to *any intellectual task* that a human being can.
#     *   **Characteristics:** It would possess consciousness, self-awareness, and the ability to learn and adapt across a wide range of tasks, similar to human intelligence.
#     *   **Status:** A long-term goal for AI research, not yet achieved.
#
# 3.  **Artificial Superintelligence (ASI):** Also hypothetical, this AI would surpass human intelligence and capability in virtually every field, including scientific creativity, general wisdom, and social skills.
#     *   **Status:** Far in the future, if ever achieved.
#
# ---
#
# ### Where Do You See AI?
#
# AI is integrated into many aspects of our daily lives:
#
# *   **Smartphones:** Voice assistants (Siri, Google Assistant), facial recognition, predictive text, camera enhancements.
# *   **Streaming Services:** Personalized recommendations (Netflix, Spotify).
# *   **E-commerce:** Product recommendations (Amazon), fraud detection.
# *   **Navigation:** Real-time traffic analysis, optimal route planning (Google Maps, Waze).
# *   **Healthcare:** Disease diagnosis (analyzing medical images), drug discovery, personalized treatment plans.
# *   **Finance:** Fraud detection, algorithmic trading, credit scoring.
# *   **Automotive:** Self-driving cars, advanced driver-assistance systems.
# *   **Customer Service:** Chatbots, virtual assistants.
# *   **Social Media:** Content moderation, personalized feeds, facial tagging.
#
# ---
#
# ### Benefits and Concerns
#
# **Benefits:**
#
# *   **Automation:** Automating repetitive and dangerous tasks.
# *   **Efficiency:** Improving speed and accuracy in many industries.
# *   **Problem Solving:** Tackling complex challenges in science, medicine, and engineering.
# *   **Personalization:** Tailoring experiences to individual users.
# *   **New Insights:** Discovering patterns in vast datasets that humans might miss.
#
# **Concerns:**
#
# *   **Job Displacement:** Automation potentially leading to job losses in some sectors.
# *   **Bias:** AI systems can perpetuate or amplify existing societal biases if trained on biased data.
# *   **Privacy:** Large-scale data collection and analysis raise privacy concerns.
# *   **Ethics:** Questions about accountability, decision-making, and the ethical use of AI (e.g., in surveillance or autonomous weapons).
# *   **Security:** Potential for malicious use of AI.
# *   **Explainability:** Some advanced AI models (especially deep learning) can be "black boxes," making it hard to understand *why* they made a particular decision.
#
# ---
#
# In essence, AI is a powerful and transformative technology that is rapidly evolving. It's not a single entity but a vast and diverse field of study and application that aims to augment human capabilities and reshape how we live and work.
